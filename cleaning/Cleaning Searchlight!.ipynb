# %% [markdown]
# # Cleaning Searchlight

# %% [markdown]
# ## PLEASE READ BELOW!

# %% [markdown]
# Thank you so much for helping GoodlyLabs clean Searchlight's Daily Congressional Database! For context, our database consists of all speeches said on the floor by both representatives and senators in the US Congress over the past 24 years. Currently, we manage all this data by storing information about the speakers (the state they represent, the party they belong to, etc.) and information about the speeches (the date it was said, the actual speech text, etc.) in two separate tables. The speakers table is about two thousand rows long, and the speeches table is about 1 million rows long. Unfortunately, with this much data, there's bound to be errors.

# %% [markdown]
# The following jupyter notebook exists so that volunteers such as yourselves can easily help us edit/clean both the speakers and speeches table. Each table has its own associated challenges and errors, which we will explain in the sections below. At the end of this notebook, you will have two final products: a cleaned speakers table and a cleaned speeches table in csv format, which you will then zip and upload to this Google Drive folder here (<url>).

# %% [markdown]
# # Initialization

# %% [markdown]
# Don't worry about the inner workings of these functions or packages, just run all of the cells below (except for the first, which you will have to edit). Later, for each section, we'll explain exactly what each corresponding function does and how you can use it.
#
# For the cell directly below, use the excel spreadsheet here (<url>) to determine what values you specifically need to fill in for the constants below.

# %%
SPEECHES_TABLE_START = 0
SPEECHES_TABLE_END = 10000
SPEAKERS_TABLE_START = 0
SPEAKERS_TABLE_END = 100
NOTEBOOK_ID = 1

#If you're curious, what these constants are doing is constraining the dataset to just 
#the small subset you have been assigned to clean.

# %%
import pandas as pd
import re
import numpy as np
import urllib
from pathlib import Path
import math

# %%
speakers = pd.read_csv('allspeakers.csv')

# %%
# speeches = pd.read_csv('allspeeches.csv')

# %%
def fix_district(index, district):
    speakers.loc[index, 'district'] = district
    print(str(speakers.loc[index, 'last_name']) + "'s district is now: " + str(speakers.loc[index, 'district']))

# %%
def fix_type(index, member_type):
    speakers.loc[index, 'type'] = member_type
    print(str(speakers.loc[index, 'last_name']) + "'s type is now: " + str(speakers.loc[index, 'type']))

# %% [markdown]
# # Cleaning Speakers

# %% [markdown]
# ## The speakers table currently has only one major error: missing missing district values.
#
# Note: It is certainly possible that your subset of the speakers table has no errors, and so if you see no errors or mistakes when cells are run, don't be alarmed. That just means you have less work to do!

# %% [markdown]
# ### Fixing District Values

# %%
# Run this cell to see which rows in the speakers table (specifically, those who are house reps,
# since senators are not assigned districts) are missing district values.
representatives = speakers[speakers['chamber'] == 'HOUSE']
representatives[representatives['district'].isnull()]
# Out:
#       speaker_id first_name   last_name chamber            type party state  \
# 25        2350.0      Jodey   ARRINGTON   HOUSE  REPRESENTATIVE     R    TX
# 34        2337.0        Don       BACON   HOUSE  REPRESENTATIVE     R    NE
# 40        1734.0      Frank    BALLANCE   HOUSE  REPRESENTATIVE     D    NC
# 42        2326.0        Jim       BANKS   HOUSE  REPRESENTATIVE     R    IN
# 44          51.0      Peter       BARCA   HOUSE  REPRESENTATIVE     D    WI
# 47          53.0        Tom      BARLOW   HOUSE  REPRESENTATIVE     D    KY
# 50        2311.0    Nanette    BARRAGAN   HOUSE  REPRESENTATIVE     D    CA
# 68          72.0    Anthony   BEILENSON   HOUSE  REPRESENTATIVE     D    CA
# 74          78.0      Helen     BENTLEY   HOUSE  REPRESENTATIVE     R    MD
# 79        2333.0       Jack     BERGMAN   HOUSE  REPRESENTATIVE     R    MI
# 83          84.0        Tom      BEVILL   HOUSE  REPRESENTATIVE     D    AL
# 87        2307.0       Andy       BIGGS   HOUSE  REPRESENTATIVE     R    AZ
# 98          93.0     Lucien   BLACKWELL   HOUSE  REPRESENTATIVE     D    PA
# 105        100.0      Peter       BLUTE   HOUSE  REPRESENTATIVE     R    MA
# 118       1723.0  Madeleine    BORDALLO   HOUSE  REPRESENTATIVE     D    GU
# 135        123.0       Bill    BREWSTER   HOUSE  REPRESENTATIVE     D    OK
# 138        127.0       Jack      BROOKS   HOUSE  REPRESENTATIVE     D    TX
# 142        130.0       Glen     BROWDER   HOUSE  REPRESENTATIVE     D    AL
# 157       2336.0        Ted        BUDD   HOUSE  REPRESENTATIVE     R    NC
# 160        145.0        Jim        BUNN   HOUSE  REPRESENTATIVE     R    OR
# 189       2310.0      Salud    CARBAJAL   HOUSE  REPRESENTATIVE     D    CA
# 198        180.0        Bob        CARR   HOUSE  REPRESENTATIVE     D    MI
# 210       1891.0     Donald    CAZAYOUX   HOUSE  REPRESENTATIVE     D    LA
# 217        190.0        Jim     CHAPMAN   HOUSE  REPRESENTATIVE     D    TX
# 218       2356.0        Liz      CHENEY   HOUSE  REPRESENTATIVE     R    WY
# 224        197.0       Dick    CHRYSLER   HOUSE  REPRESENTATIVE     R    MI
# 234       1790.0    Emanuel     CLEAVER   HOUSE  REPRESENTATIVE     D    MO
# 237        207.0    William     CLINGER   HOUSE  REPRESENTATIVE     R    PA
# 245       1878.0      Steve       COHEN   HOUSE  REPRESENTATIVE     D    TN
# 253       2297.0      James       COMER   HOUSE  REPRESENTATIVE     R    KY
# ...          ...        ...         ...     ...             ...   ...   ...
# 1222      1121.0      Gerry      STUDDS   HOUSE  REPRESENTATIVE     D    MA
# 1228      1125.0        Don   SUNDQUIST   HOUSE  REPRESENTATIVE     R    TN
# 1230      2341.0     Thomas      SUOZZI   HOUSE  REPRESENTATIVE     D    NY
# 1234      1128.0       Dick       SWETT   HOUSE  REPRESENTATIVE     D    NH
# 1235      1129.0         Al       SWIFT   HOUSE  REPRESENTATIVE     D    WA
# 1236      1133.0       Mike       SYNAR   HOUSE  REPRESENTATIVE     D    OK
# 1242      1138.0      Randy        TATE   HOUSE  REPRESENTATIVE     R    WA
# 1246      2351.0      Scott      TAYLOR   HOUSE  REPRESENTATIVE     R    VA
# 1248      2351.0      Scott      TAYLOR   HOUSE  REPRESENTATIVE     R    VA
# 1249      2351.0      Scott      TAYLOR   HOUSE  REPRESENTATIVE     R    VA
# 1250      2351.0      Scott      TAYLOR   HOUSE  REPRESENTATIVE     R    VA
# 1251      2351.0      Scott      TAYLOR   HOUSE  REPRESENTATIVE     R    VA
# 1253      1147.0      Frank      TEJEDA   HOUSE  REPRESENTATIVE     D    TX
# 1254      2344.0    Claudia      TENNEY   HOUSE  REPRESENTATIVE     R    NY
# 1264      1156.0        Ray    THORNTON   HOUSE  REPRESENTATIVE     D    AR
# 1277      1161.0      Peter  TORKILDSEN   HOUSE  REPRESENTATIVE     R    MA
# 1285      1172.0     Walter      TUCKER   HOUSE  REPRESENTATIVE     D    CA
# 1291      1175.0     Robert   UNDERWOOD   HOUSE  REPRESENTATIVE     D    GU
# 1292      1176.0     Jolene     UNSOELD   HOUSE  REPRESENTATIVE     D    WA
# 1295      1178.0        Tim   VALENTINE   HOUSE  REPRESENTATIVE     D    NC
# 1305      1189.0     Harold     VOLKMER   HOUSE  REPRESENTATIVE     D    MO
# 1306      1190.0    Barbara  VUCANOVICH   HOUSE  REPRESENTATIVE     R    NV
# 1310      1192.0       Enid   WALDHOLTZ   HOUSE  REPRESENTATIVE     R    UT
# 1320      1201.0       Mike        WARD   HOUSE  REPRESENTATIVE     D    KY
# 1324      1203.0      Craig  WASHINGTON   HOUSE  REPRESENTATIVE     D    TX
# 1348      1218.0       Alan       WHEAT   HOUSE  REPRESENTATIVE     D    MO
# 1352      1225.0      Jamie     WHITTEN   HOUSE  REPRESENTATIVE     D    MS
# 1358      1232.0    Charles      WILSON   HOUSE  REPRESENTATIVE     D    TX
# 1379      1263.0    William      ZELIFF   HOUSE  REPRESENTATIVE     R    NH
# 1380      1264.0       Dick      ZIMMER   HOUSE  REPRESENTATIVE     R    NJ
#
#       district bio_guide_id  congress_id
# 25         NaN      A000375        115.0
# 34         NaN      B001298        115.0
# 40         NaN      B001238        108.0
# 42         NaN      B001299        115.0
# 44         NaN      B001226        103.0
# 47         NaN      B000151        103.0
# 50         NaN      B001300        115.0
# 68         NaN      B000318        103.0
# 74         NaN      B000392        103.0
# 79         NaN      B001301        115.0
# 83         NaN      B000431        103.0
# 87         NaN      B001302        115.0
# 98         NaN      B000517        103.0
# 105        NaN      B000576        103.0
# 118        NaN      B001245        115.0
# 135        NaN      B000817        103.0
# 138        NaN      B000880        103.0
# 142        NaN      B000897        103.0
# 157        NaN      B001305        115.0
# 160        NaN      B001063        104.0
# 189        NaN      C001112        115.0
# 198        NaN      C000178        103.0
# 210        NaN      C001073        110.0
# 217        NaN      C000312        103.0
# 218        NaN      C001109        115.0
# 224        NaN      C000385        104.0
# 234        NaN      C001061        115.0
# 237        NaN      C000523        103.0
# 245        NaN      C001068        115.0
# 253        NaN      C001108        115.0
# ...        ...          ...          ...
# 1222       NaN      S001040        103.0
# 1228       NaN      S001075        103.0
# 1230       NaN      S001201        115.0
# 1234       NaN      S001113        103.0
# 1235       NaN      S001115        103.0
# 1236       NaN      S001139        103.0
# 1242       NaN      T000048        104.0
# 1246       NaN      T000477        115.0
# 1248       NaN      T000477        115.0
# 1249       NaN      T000477        115.0
# 1250       NaN      T000477        115.0
# 1251       NaN      T000477        115.0
# 1253       NaN      T000113        104.0
# 1254       NaN      T000478        115.0
# 1264       NaN      T000243        103.0
# 1277       NaN      T000314        103.0
# 1285       NaN      T000405        103.0
# 1291       NaN      U000014        103.0
# 1292       NaN      U000017        103.0
# 1295       NaN      V000006        103.0
# 1305       NaN      V000112        103.0
# 1306       NaN      V000124        103.0
# 1310       NaN      G000408        104.0
# 1320       NaN      W000139        104.0
# 1324       NaN      W000177        103.0
# 1348       NaN      W000326        103.0
# 1352       NaN      W000428        103.0
# 1358       NaN      W000570        103.0
# 1379       NaN      Z000004        103.0
# 1380       NaN      Z000008        103.0
#
# [179 rows x 10 columns]

# %% [markdown]
# Above, each row represents a congress member. Observe that the table above has a NaN value for each entry in the "district" column. To fix the district values in your subset of the database, you will be using the "fix_district" function. This function takes in two inputs: "index", the index of the row (which can be found in the left most column in bold), and "district", the district of the congressmember in the row.
#
# For each congressmember above, look up their first and last name in a search engine of your choice, and find which congressional district they represented in their state (1st district, 2nd district, etc). If they belong to a state which only has a single, at-large district, then consider that the 1st district. The value you will enter for the "district" input to fix_district is the integer value of their district.
#
# So, for example, if the index of the congress member's row who you were trying to fix was 48, and your congress member represented the 33rd district of their state, you would enter: "fix_district(48, 33)" in the cell below. You should see a print message confirming that the senator's district has been changed.
#
# Example print message: "APPLEGATE's district is now: 33.0"

# %%
fix_district("fill", "fill")
# Out:
# APPLEGATE's district is now: 33.0

# %% [markdown]
# Repeat the process above until there are no more representatives left in your subset of the dataset that are missing district values. You can keep repeatedly running the cell underneath the subheading "Fixing District Values" to check how many representatives' district you have left to update.

# %% [markdown]
# # Cleaning Speeches

# %% [markdown]
# ## The speeches table currently has two major errors: missing speaker_id values and missing proceeding_title values.
#
# Note: It is certainly possible that your subset of the speakers table has no errors, and so if you see no errors or mistakes when cells are run, don't be alarmed. That just means you have less work to do!

# %%
speeches.columns
# Out:
# Index(['speech_id', 'topic_id', 'word_count', 'speech_text', 'file_name',
#        'mods_file', 'speaker_id', 'proceeding_title', 'year', 'month', 'day'],
#       dtype='object')

# %%
speeches[speeches['speaker_id'].isnull()]
# Out:
#          speech_id  topic_id  word_count  \
# 36              36  topic_id          95
# 40              40  topic_id         266
# 42              42  topic_id         198
# 319            319  topic_id           8
# 321            321  topic_id         238
# 323            323  topic_id          10
# 325            325  topic_id         107
# 328            328  topic_id        3717
# 331            331  topic_id          39
# 682            682  topic_id          48
# 683            683  topic_id         566
# 687            687  topic_id          21
# 688            688  topic_id        1058
# 692            692  topic_id          26
# 693            693  topic_id          22
# 695            695  topic_id          13
# 706            706  topic_id          25
# 717            717  topic_id          43
# 764            764  topic_id        2067
# 765            765  topic_id           8
# 767            767  topic_id         752
# 1303          1303  topic_id         365
# 1305          1305  topic_id         172
# 1308          1308  topic_id          31
# 1320          1320  topic_id          12
# 1398          1398  topic_id          17
# 1405          1405  topic_id         620
# 1430          1430  topic_id        1368
# 1431          1431  topic_id           9
# 1438          1438  topic_id         128
# ...            ...       ...         ...
# 1116684    1116684  topic_id           5
# 1117083    1117083  topic_id          27
# 1117709    1117709  topic_id          30
# 1117710    1117710  topic_id         798
# 1117711    1117711  topic_id          34
# 1117786    1117786  topic_id         298
# 1118501    1118501  topic_id         350
# 1119544    1119544  topic_id         532
# 1119845    1119845  topic_id         478
# 1120055    1120055  topic_id         367
# 1120089    1120089  topic_id         670
# 1120136    1120136  topic_id         467
# 1120475    1120475  topic_id         449
# 1120520    1120520  topic_id         849
# 1121263    1121263  topic_id          24
# 1121398    1121398  topic_id         785
# 1121500    1121500  topic_id         246
# 1121629    1121629  topic_id         637
# 1121917    1121917  topic_id         393
# 1121950    1121950  topic_id          24
# 1121951    1121951  topic_id         735
# 1122164    1122164  topic_id          96
# 1122374    1122374  topic_id        1677
# 1122383    1122383  topic_id         817
# 1122664    1122664  topic_id         492
# 1122871    1122871  topic_id          26
# 1123653    1123653  topic_id          28
# 1123654    1123654  topic_id        1158
# 1123920    1123920  topic_id         133
# 1123992    1123992  topic_id         141
#
#                                                speech_text  \
# 36       Mr.President, on February 2, 1994, the Committ...
# 40       Mr.President, a group of us from the leadershi...
# 42       I thank the distinguished manager.  Let me rep...
# 319      Mr.President, will the Senator yield for a que...
# 321      Mr.President, the Senator from Illinois, my di...
# 323      You will be telling how old we are. Be careful.
# 325      This is a stand-alone resolution. I have never...
# 328      Mr.President, I thank the Senator from Nevada ...
# 331      I suggest the absence of a quorum, with the ti...
# 682      Mr.President, just one parliamentary inquiry. ...
# 683      Thank you, Mr. Mr.President, I am anticipating...
# 687      Mr.President, how much time do I have on our s...
# 688      I thank the  Mr.President, I yield myself 4 mi...
# 692      Mr.President, how much time do I have remainin...
# 693      I think the Senator from Massachusetts should ...
# 695      Mr.President, I yield the remainder of my time...
# 706      The American Legion, the VFW, Disabled Veteran...
# 717      I move to lay that motion on the table.  The m...
# 764      Mr.President, thank you. I would like to, firs...
# 765         Will the Senator yield me another 5 minutes?
# 767      Mr.President, let me again, one last time, quo...
# 1303     Mr.President, I have had a chance to chat with...
# 1305     Let me complete this thought. To raise funds, ...
# 1308     Mr.President, I ask unanimous consent to withd...
# 1320     We have the potential of other amendments but ...
# 1398     I announce that the Senator from Montana [Mr.B...
# 1405     Madam President, it is awfully hard to underst...
# 1430     Madam President, carved over the library entra...
# 1431     I yield the floor.  The PRESIDING The Senator ...
# 1438     Madam President, some of the colleagues would ...
# ...                                                    ...
# 1116684        Homer       (7) Mr.Robert Ernest       (8)
# 1117083  Mr.President, Californians and San Franciscans...
# 1117709  Mr.President, I ask unanimous consent that I b...
# 1117710  Thank you.  Mr.President, in a few minutes, we...
# 1117711  Mr.President, I ask for the yeas and nays.  Th...
# 1117786  Mr.Speaker, I am honored to take this oath and...
# 1118501  Mr.Speaker, I rise to honor the lives of Lieut...
# 1119544  Mr.Speaker, I rise today so that we can finish...
# 1119845  Mr.President, I have 6 requests for committees...
# 1120055  Mr.President, I rise today briefly to thank Pr...
# 1120089  Mr.President, I have 12 requests for committee...
# 1120136  Mr.President, California and the nation lost a...
# 1120475  Mr.Speaker, the VA MISSION Act is a good bill....
# 1120520  Mr.Chair, I include in the Record the followin...
# 1121263  Mr.President, I suggest the absence of a quoru...
# 1121398  Mr.Speaker, I rise today to ask my colleagues ...
# 1121500  Madam Speaker, the Tax Cuts and Jobs Act has i...
# 1121629  Mr.Speaker, ``For conspicuous gallantry and in...
# 1121917  Mr.President, I have 6 requests for committees...
# 1121950  Mr.President, I ask unanimous consent that the...
# 1121951  Mr.President, I rise to discuss, once again, a...
# 1122164  Can I just offer, a great Democrat Hubert Hump...
# 1122374  Mr.President, I want to thank Senator Merkley ...
# 1122383  Mr.Speaker, this week is National Police Week,...
# 1122664  Mr.Speaker, I thank Mr.Dunn, my fellow Floridi...
# 1122871  Mr.President, I ask unanimous consent that the...
# 1123653  Mr.President, I ask unanimous consent that the...
# 1123654  Mr.President, I rise today because, in my judg...
# 1123920  Mr.Speaker, I want to thank you and the Member...
# 1123992  Mr.Speaker, I rise today in support of H.4760,...
#
#                                  file_name                          mods_file  \
# 36           CREC-1994-03-02-pt1-PgS56.txt      CREC-1994-03-02-pt1-PgS56.xml
# 40           CREC-1994-02-25-pt1-PgH14.txt      CREC-1994-02-25-pt1-PgH14.xml
# 42           CREC-1994-02-25-pt1-PgH14.txt      CREC-1994-02-25-pt1-PgH14.xml
# 319          CREC-1994-02-25-pt1-PgH15.txt      CREC-1994-02-25-pt1-PgH15.xml
# 321          CREC-1994-02-25-pt1-PgH15.txt      CREC-1994-02-25-pt1-PgH15.xml
# 323          CREC-1994-02-25-pt1-PgH15.txt      CREC-1994-02-25-pt1-PgH15.xml
# 325          CREC-1994-02-25-pt1-PgH15.txt      CREC-1994-02-25-pt1-PgH15.xml
# 328          CREC-1994-02-25-pt1-PgH15.txt      CREC-1994-02-25-pt1-PgH15.xml
# 331          CREC-1994-02-25-pt1-PgH15.txt      CREC-1994-02-25-pt1-PgH15.xml
# 682           CREC-1994-01-27-pt1-PgH4.txt       CREC-1994-01-27-pt1-PgH4.xml
# 683           CREC-1994-01-27-pt1-PgH4.txt       CREC-1994-01-27-pt1-PgH4.xml
# 687           CREC-1994-01-27-pt1-PgH4.txt       CREC-1994-01-27-pt1-PgH4.xml
# 688           CREC-1994-01-27-pt1-PgH4.txt       CREC-1994-01-27-pt1-PgH4.xml
# 692           CREC-1994-01-27-pt1-PgH4.txt       CREC-1994-01-27-pt1-PgH4.xml
# 693           CREC-1994-01-27-pt1-PgH4.txt       CREC-1994-01-27-pt1-PgH4.xml
# 695           CREC-1994-01-27-pt1-PgH4.txt       CREC-1994-01-27-pt1-PgH4.xml
# 706           CREC-1994-01-27-pt1-PgH4.txt       CREC-1994-01-27-pt1-PgH4.xml
# 717           CREC-1994-01-27-pt1-PgH4.txt       CREC-1994-01-27-pt1-PgH4.xml
# 764           CREC-1994-02-25-pt1-PgH5.txt       CREC-1994-02-25-pt1-PgH5.xml
# 765           CREC-1994-02-25-pt1-PgH5.txt       CREC-1994-02-25-pt1-PgH5.xml
# 767           CREC-1994-02-25-pt1-PgH5.txt       CREC-1994-02-25-pt1-PgH5.xml
# 1303         CREC-1994-01-27-pt1-PgH10.txt      CREC-1994-01-27-pt1-PgH10.xml
# 1305         CREC-1994-01-27-pt1-PgH10.txt      CREC-1994-01-27-pt1-PgH10.xml
# 1308         CREC-1994-01-27-pt1-PgH10.txt      CREC-1994-01-27-pt1-PgH10.xml
# 1320         CREC-1994-01-27-pt1-PgH10.txt      CREC-1994-01-27-pt1-PgH10.xml
# 1398         CREC-1994-01-27-pt1-PgH10.txt      CREC-1994-01-27-pt1-PgH10.xml
# 1405         CREC-1994-01-27-pt1-PgH10.txt      CREC-1994-01-27-pt1-PgH10.xml
# 1430         CREC-1994-01-27-pt1-PgH10.txt      CREC-1994-01-27-pt1-PgH10.xml
# 1431         CREC-1994-01-27-pt1-PgH10.txt      CREC-1994-01-27-pt1-PgH10.xml
# 1438         CREC-1994-01-27-pt1-PgH10.txt      CREC-1994-01-27-pt1-PgH10.xml
# ...                                    ...                                ...
# 1116684    CREC-2018-04-26-pt1-PgS2491.txt    CREC-2018-04-26-pt1-PgS2491.xml
# 1117083  CREC-2018-04-23-pt1-PgS2340-2.txt  CREC-2018-04-23-pt1-PgS2340-2.xml
# 1117709  CREC-2018-04-24-pt1-PgS2369-2.txt  CREC-2018-04-24-pt1-PgS2369-2.xml
# 1117710  CREC-2018-04-24-pt1-PgS2369-2.txt  CREC-2018-04-24-pt1-PgS2369-2.xml
# 1117711  CREC-2018-04-24-pt1-PgS2369-2.txt  CREC-2018-04-24-pt1-PgS2369-2.xml
# 1117786  CREC-2018-04-12-pt1-PgH3194-2.txt  CREC-2018-04-12-pt1-PgH3194-2.xml
# 1118501  CREC-2018-03-21-pt1-PgH1750-2.txt  CREC-2018-03-21-pt1-PgH1750-2.xml
# 1119544  CREC-2018-06-07-pt1-PgH4862-2.txt  CREC-2018-06-07-pt1-PgH4862-2.xml
# 1119845    CREC-2018-05-24-pt1-PgS2942.txt    CREC-2018-05-24-pt1-PgS2942.xml
# 1120055  CREC-2018-06-13-pt1-PgS3864-3.txt  CREC-2018-06-13-pt1-PgS3864-3.xml
# 1120089    CREC-2018-06-13-pt1-PgS3924.txt    CREC-2018-06-13-pt1-PgS3924.xml
# 1120136    CREC-2018-06-14-pt1-PgS3949.txt    CREC-2018-06-14-pt1-PgS3949.xml
# 1120475  CREC-2018-05-16-pt1-PgH3991-2.txt  CREC-2018-05-16-pt1-PgH3991-2.xml
# 1120520  CREC-2018-05-23-pt1-PgH4673-2.txt  CREC-2018-05-23-pt1-PgH4673-2.xml
# 1121263  CREC-2018-06-19-pt1-PgS4012-5.txt  CREC-2018-06-19-pt1-PgS4012-5.xml
# 1121398    CREC-2018-06-13-pt1-PgH5127.txt    CREC-2018-06-13-pt1-PgH5127.xml
# 1121500  CREC-2018-06-12-pt1-PgH5083-2.txt  CREC-2018-06-12-pt1-PgH5083-2.xml
# 1121629  CREC-2018-05-23-pt1-PgH4588-3.txt  CREC-2018-05-23-pt1-PgH4588-3.xml
# 1121917    CREC-2018-06-05-pt1-PgS2997.txt    CREC-2018-06-05-pt1-PgS2997.xml
# 1121950  CREC-2018-06-26-pt1-PgS4382-2.txt  CREC-2018-06-26-pt1-PgS4382-2.xml
# 1121951  CREC-2018-06-26-pt1-PgS4382-2.txt  CREC-2018-06-26-pt1-PgS4382-2.xml
# 1122164  CREC-2018-06-26-pt1-PgH5656-3.txt  CREC-2018-06-26-pt1-PgH5656-3.xml
# 1122374  CREC-2018-06-20-pt1-PgS4293-6.txt  CREC-2018-06-20-pt1-PgS4293-6.xml
# 1122383    CREC-2018-05-15-pt1-PgH3942.txt    CREC-2018-05-15-pt1-PgH3942.xml
# 1122664    CREC-2018-05-21-pt1-PgH4254.txt    CREC-2018-05-21-pt1-PgH4254.xml
# 1122871  CREC-2018-06-13-pt1-PgS3864-2.txt  CREC-2018-06-13-pt1-PgS3864-2.xml
# 1123653    CREC-2018-06-05-pt1-PgS2982.txt    CREC-2018-06-05-pt1-PgS2982.xml
# 1123654    CREC-2018-06-05-pt1-PgS2982.txt    CREC-2018-06-05-pt1-PgS2982.xml
# 1123920    CREC-2018-05-16-pt1-PgH3990.txt    CREC-2018-05-16-pt1-PgH3990.xml
# 1123992  CREC-2018-06-21-pt1-PgH5380-2.txt  CREC-2018-06-21-pt1-PgH5380-2.xml
#
#          speaker_id                                   proceeding_title  year  \
# 36              NaN                                                NaN  1994
# 40              NaN                                                NaN  1994
# 42              NaN                                                NaN  1994
# 319             NaN                                                NaN  1994
# 321             NaN                                                NaN  1994
# 323             NaN                                                NaN  1994
# 325             NaN                                                NaN  1994
# 328             NaN                                                NaN  1994
# 331             NaN                                                NaN  1994
# 682             NaN                                                NaN  1994
# 683             NaN                                                NaN  1994
# 687             NaN                                                NaN  1994
# 688             NaN                                                NaN  1994
# 692             NaN                                                NaN  1994
# 693             NaN                                                NaN  1994
# 695             NaN                                                NaN  1994
# 706             NaN                                                NaN  1994
# 717             NaN                                                NaN  1994
# 764             NaN                                                NaN  1994
# 765             NaN                                                NaN  1994
# 767             NaN                                                NaN  1994
# 1303            NaN                                                NaN  1994
# 1305            NaN                                                NaN  1994
# 1308            NaN                                                NaN  1994
# 1320            NaN                                                NaN  1994
# 1398            NaN                                                NaN  1994
# 1405            NaN                                                NaN  1994
# 1430            NaN                                                NaN  1994
# 1431            NaN                                                NaN  1994
# 1438            NaN                                                NaN  1994
# ...             ...                                                ...   ...
# 1116684         NaN  SENATE RESOLUTION 488--HONORING THE 100TH ANNI...  2018
# 1117083         NaN                             REMEMBERING DORIS WARD  2018
# 1117709         NaN                      EXECUTIVE CALENDAR--Continued  2018
# 1117710         NaN                      EXECUTIVE CALENDAR--Continued  2018
# 1117711         NaN                      EXECUTIVE CALENDAR--Continued  2018
# 1117786         NaN  WELCOMING THE HONORABLE CONOR LAMB TO THE HOUS...  2018
# 1118501         NaN  MOMENT OF SILENCE HONORING LIEUTENANT COMMANDE...  2018
# 1119544         NaN  PROVIDING FOR FURTHER CONSIDERATION OF H.R. 58...  2018
# 1119845         NaN                   AUTHORITY FOR COMMITTEES TO MEET  2018
# 1120055         NaN                                   TRUMP-KIM SUMMIT  2018
# 1120089         NaN                   AUTHORITY FOR COMMITTEES TO MEET  2018
# 1120136         NaN                             REMEMBERING EDDIE FUNG  2018
# 1120475         NaN  PROVIDING FOR CONSIDERATION OF H.R. 5698, PROT...  2018
# 1120520         NaN  NATIONAL DEFENSE AUTHORIZATION ACT FOR FISCAL ...  2018
# 1121263         NaN  ENERGY AND WATER, LEGISLATIVE BRANCH, AND MILI...  2018
# 1121398         NaN  IMPROVING THE FEDERAL RESPONSE TO FAMILIES IMP...  2018
# 1121500         NaN               GOOD THINGS HAPPENING IN OUR ECONOMY  2018
# 1121629         NaN                                 THE MEDAL OF HONOR  2018
# 1121917         NaN                   AUTHORITY FOR COMMITTEES TO MEET  2018
# 1121950         NaN  AGRICULTURE AND NUTRITION ACT OF 2018--MOTION ...  2018
# 1121951         NaN  AGRICULTURE AND NUTRITION ACT OF 2018--MOTION ...  2018
# 1122164         NaN              PROCEEDINGS OF FORMER MEMBERS PROGRAM  2018
# 1122374         NaN                           FORCED FAMILY SEPARATION  2018
# 1122383         NaN  EXPRESSING SENSE OF HOUSE THAT CONGRESS AND TH...  2018
# 1122664         NaN  SERVICEMEMBERS IMPROVED TRANSITION THROUGH REF...  2018
# 1122871         NaN          MEASURE PLACED ON THE CALENDAR--H.R. 5895  2018
# 1123653         NaN                                 EXECUTIVE CALENDAR  2018
# 1123654         NaN                                 EXECUTIVE CALENDAR  2018
# 1123920         NaN  REPRESENTING ARIZONA'S EIGHTH CONGRESSIONAL DI...  2018
# 1123992         NaN              SECURING AMERICA'S FUTURE ACT OF 2018  2018
#
#             month  day
# 36          March    2
# 40       February   25
# 42       February   25
# 319      February   25
# 321      February   25
# 323      February   25
# 325      February   25
# 328      February   25
# 331      February   25
# 682       January   27
# 683       January   27
# 687       January   27
# 688       January   27
# 692       January   27
# 693       January   27
# 695       January   27
# 706       January   27
# 717       January   27
# 764      February   25
# 765      February   25
# 767      February   25
# 1303      January   27
# 1305      January   27
# 1308      January   27
# 1320      January   27
# 1398      January   27
# 1405      January   27
# 1430      January   27
# 1431      January   27
# 1438      January   27
# ...           ...  ...
# 1116684     April   26
# 1117083     April   23
# 1117709     April   24
# 1117710     April   24
# 1117711     April   24
# 1117786     April   12
# 1118501     March   21
# 1119544      June    7
# 1119845       May   24
# 1120055      June   13
# 1120089      June   13
# 1120136      June   14
# 1120475       May   16
# 1120520       May   23
# 1121263      June   19
# 1121398      June   13
# 1121500      June   12
# 1121629       May   23
# 1121917      June    5
# 1121950      June   26
# 1121951      June   26
# 1122164      June   26
# 1122374      June   20
# 1122383       May   15
# 1122664       May   21
# 1122871      June   13
# 1123653      June    5
# 1123654      June    5
# 1123920       May   16
# 1123992      June   21
#
# [3442 rows x 11 columns]
